# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob as glob
import matplotlib.pyplot as plt
import random
import cv2
import util

# %% [markdown]
# ### Visualizing the data

# %%
# Load the coco128.yaml file
yaml_file_path = '../data/coco128.yaml'
coco128_data = util.load_yaml(yaml_file_path)

# Extract class names from the yaml data
class_names = coco128_data['names']

# %%
# Visualize the dataset
all_images,all_labels = util.plot(
    image_paths='../../dataset/coco128/images/train2017',
    label_paths='../../dataset/coco128/labels/train2017',
    num_samples=4,
    class_names=class_names
)
# Out:
# Found 126 matching image-label pairs.
